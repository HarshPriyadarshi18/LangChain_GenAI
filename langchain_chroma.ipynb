# %%
# !pip install langchain chromadb openai tiktoken pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (1.3.14)
# Requirement already satisfied: chromadb in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (1.5.9)
# Requirement already satisfied: openai in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (2.53.0)
# Requirement already satisfied: tiktoken in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (0.13.0)
# Requirement already satisfied: pypdf in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (6.14.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain) (1.5.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain) (1.2.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.1)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (2.2.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.27.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from openai) (0.16.0)
# Requirement already satisfied: regex in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: pyproject_hooks in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.5)
# Requirement already satisfied: flatbuffers in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from tokenizers>=0.13.2->chromadb) (1.26.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
# !pip install langchain_openai langchain_community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain_openai in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (1.4.1)
# Requirement already satisfied: langchain_community in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (0.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_openai) (1.5.3)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_openai) (2.53.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain_openai) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (3.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from openai<3.0.0,>=2.45.0->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.1->langchain_openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.1->langchain_openai) (0.4.2)
# Requirement already satisfied: regex in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (2.2.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain_community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_openai) (2.5.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.4)
# Requirement already satisfied: colorama in C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain_openai) (0.4.6)
# [notice] A new release of pip is available: 26.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.embeddings import FakeEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
# Out:
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_42660\493604626.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import Chroma

# %%
# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs=[doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=FakeEmbeddings(size=1536),
    persist_directory="./chroma_db",
)

# %%
vector_store.add_documents(docs)
# Out:
# ['ba7295f6-1adc-4adf-b3c1-a35e25db592f',
#  '2de0d482-bd3e-46f4-90a1-6161fb8cc347',
#  '8f068b6a-1bd1-4de6-881b-effb99f6ab67',
#  'a13bf4b6-0700-454e-99d4-e6e4bc6e9090',
#  '250154db-8906-492a-8d34-03f0153fcd3c']

# %%
vector_store.get(include=['embeddings', 'metadatas', 'documents'])
# Out:
# {'ids': ['ba7295f6-1adc-4adf-b3c1-a35e25db592f',
#   '2de0d482-bd3e-46f4-90a1-6161fb8cc347',
#   '8f068b6a-1bd1-4de6-881b-effb99f6ab67',
#   'a13bf4b6-0700-454e-99d4-e6e4bc6e9090',
#   '250154db-8906-492a-8d34-03f0153fcd3c'],
#  'embeddings': array([[ 0.07670867,  1.95859599,  1.26183403, ..., -0.42155239,
#          -0.3496066 ,  0.2749306 ],
#         [-0.30248359,  0.27544534, -0.04919863, ..., -1.20765257,
#           0.8075276 , -1.97614276],
#         [ 0.06074941,  1.32147133,  0.95773685, ...,  0.24091631,
#           0.25148934,  1.0541147 ],
#         [ 0.130707  ,  1.49341214, -0.07123896, ..., -1.45318818,
#          -0.53138506, -0.8268438 ],
#         [ 1.71053231, -0.65532321,  0.36191776, ..., -1.46840155,
#          -0.03564204,  0.80731046]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.similarity_search(
    query="Who is the best captain in IPL history?",
    k=1
)
# Out:
# [Document(id='ba7295f6-1adc-4adf-b3c1-a35e25db592f', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.')]

# %%
vector_store.similarity_search_with_score(
    query="Who is the best captain in IPL history?",
    k=1
)
# Out:
# [(Document(id='8f068b6a-1bd1-4de6-881b-effb99f6ab67', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   2936.566650390625)]

# %%
vector_store.similarity_search_with_score(
    query="",
    k=1
)
# Out:
# [(Document(id='8f068b6a-1bd1-4de6-881b-effb99f6ab67', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   2926.1005859375)]
